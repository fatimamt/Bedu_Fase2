# %% [markdown]
# # APIs

# %% [markdown]
# Queremos saber que tanto afectaron las fiestas decembrinas en el número de casos nuevos en el mes de Enero para México. Para esto utilizaremos la API https://covid19tracking.narrativa.com/es/mexico/api.html

# %%
#Importacion de modulos
import pandas as pd
import requests

# %% [markdown]
# Por la documentación de la API, sabemos como pedir los datos por día

# %%
data_days = []
for day in range(1, 32):
    day = "0" + str(day) if day < 10 else str(day)
    r = requests.get(f"https://api.covid19tracking.narrativa.com/api/2021-01-{day}/country/mexico")
    data_days.append(r.json())

# %% [markdown]
# Revisamos la estructura que nos devolvió la consulta

# %%
data_days[0]
# Out:
# {'dates': {'2021-01-01': {'countries': {'Mexico': {'date': '2021-01-01',
#      'id': 'mexico',
#      'links': [{'href': '/api/2021-01-01/country/mexico',
#        'rel': 'self',
#        'type': 'GET'}],
#      'name': 'Mexico',
#      'name_es': 'México',
#      'name_it': 'Messico',
#      'regions': [{'date': '2021-01-01',
#        'id': 'morelos',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/morelos',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Morelos',
#        'name_es': 'Morelos',
#        'name_it': 'Morelos',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 9930,
#        'today_deaths': 1456,
#        'today_intensive_care': 49,
#        'today_new_confirmed': 112,
#        'today_new_deaths': 9,
#        'today_new_intensive_care': 49,
#        'today_new_open_cases': 103,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 2843,
#        'today_recovered': 5631,
#        'today_total_hospitalised_patients': 795,
#        'today_vs_yesterday_confirmed': 0.011407618659604823,
#        'today_vs_yesterday_deaths': 0.0062197650310988895,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.03759124087591248,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 9818,
#        'yesterday_deaths': 1447,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 2740,
#        'yesterday_recovered': 5631,
#        'yesterday_total_hospitalised_patients': 795},
#       {'date': '2021-01-01',
#        'id': 'guerrero',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/guerrero',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Guerrero',
#        'name_es': 'Guerrero',
#        'name_it': 'Guerrero',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 26024,
#        'today_deaths': 2716,
#        'today_intensive_care': 115,
#        'today_new_confirmed': 50,
#        'today_new_deaths': 13,
#        'today_new_intensive_care': 115,
#        'today_new_open_cases': 37,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 3299,
#        'today_recovered': 20009,
#        'today_total_hospitalised_patients': 807,
#        'today_vs_yesterday_confirmed': 0.0019250019250018902,
#        'today_vs_yesterday_deaths': 0.004809470958194506,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.01134273451870027,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 25974,
#        'yesterday_deaths': 2703,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 3262,
#        'yesterday_recovered': 20009,
#        'yesterday_total_hospitalised_patients': 807},
#       {'date': '2021-01-01',
#        'id': 'baja_california_sur',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/baja_california_sur',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Baja California Sur',
#        'name_es': 'Baja California Sur',
#        'name_it': 'Baja California Sur',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 17820,
#        'today_deaths': 784,
#        'today_intensive_care': 11,
#        'today_new_confirmed': 141,
#        'today_new_deaths': 9,
#        'today_new_intensive_care': 11,
#        'today_new_open_cases': 132,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 5135,
#        'today_recovered': 11901,
#        'today_total_hospitalised_patients': 122,
#        'today_vs_yesterday_confirmed': 0.007975564228746013,
#        'today_vs_yesterday_deaths': 0.011612903225806548,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.026384169498300913,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 17679,
#        'yesterday_deaths': 775,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 5003,
#        'yesterday_recovered': 11901,
#        'yesterday_total_hospitalised_patients': 122},
#       {'date': '2021-01-01',
#        'id': 'ciudad_de_mexico',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/ciudad_de_mexico',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Ciudad de México',
#        'name_es': 'Ciudad de México',
#        'name_it': 'Ciudad de México',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 334137,
#        'today_deaths': 16873,
#        'today_intensive_care': 916,
#        'today_new_confirmed': 3864,
#        'today_new_deaths': 119,
#        'today_new_intensive_care': 916,
#        'today_new_open_cases': 3745,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 1,
#        'today_open_cases': 174936,
#        'today_recovered': 142328,
#        'today_total_hospitalised_patients': 10333,
#        'today_vs_yesterday_confirmed': 0.01169941230436633,
#        'today_vs_yesterday_deaths': 0.007102781425331273,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.02187615003125165,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 9.678668215262753e-05,
#        'yesterday_confirmed': 330273,
#        'yesterday_deaths': 16754,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 171191,
#        'yesterday_recovered': 142328,
#        'yesterday_total_hospitalised_patients': 10332},
#       {'date': '2021-01-01',
#        'id': 'baja_california',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/baja_california',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Baja California',
#        'name_es': 'Baja California',
#        'name_it': 'Baja California',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 34889,
#        'today_deaths': 5559,
#        'today_intensive_care': 59,
#        'today_new_confirmed': 312,
#        'today_new_deaths': 35,
#        'today_new_intensive_care': 59,
#        'today_new_open_cases': 277,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 10415,
#        'today_recovered': 18915,
#        'today_total_hospitalised_patients': 2755,
#        'today_vs_yesterday_confirmed': 0.009023339213928283,
#        'today_vs_yesterday_deaths': 0.006335988414192695,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.02732294338133756,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 34577,
#        'yesterday_deaths': 5524,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 10138,
#        'yesterday_recovered': 18915,
#        'yesterday_total_hospitalised_patients': 2755},
#       {'date': '2021-01-01',
#        'id': 'quintana_roo',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/quintana_roo',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Quintana Roo',
#        'name_es': 'Quintana Roo',
#        'name_it': 'Quintana Roo',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 15968,
#        'today_deaths': 2031,
#        'today_intensive_care': 151,
#        'today_new_confirmed': 113,
#        'today_new_deaths': 3,
#        'today_new_intensive_care': 151,
#        'today_new_open_cases': 110,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 2264,
#        'today_recovered': 11673,
#        'today_total_hospitalised_patients': 929,
#        'today_vs_yesterday_confirmed': 0.00712708924629446,
#        'today_vs_yesterday_deaths': 0.0014792899408284654,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.05106778087279484,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 15855,
#        'yesterday_deaths': 2028,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 2154,
#        'yesterday_recovered': 11673,
#        'yesterday_total_hospitalised_patients': 929},
#       {'date': '2021-01-01',
#        'id': 'tlaxcala',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/tlaxcala',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Tlaxcala',
#        'name_es': 'Tlaxcala',
#        'name_it': 'Tlaxcala',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 11351,
#        'today_deaths': 1420,
#        'today_intensive_care': 111,
#        'today_new_confirmed': 217,
#        'today_new_deaths': 5,
#        'today_new_intensive_care': 111,
#        'today_new_open_cases': 212,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 2609,
#        'today_recovered': 7322,
#        'today_total_hospitalised_patients': 432,
#        'today_vs_yesterday_confirmed': 0.01948985090713129,
#        'today_vs_yesterday_deaths': 0.0035335689045936647,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.0884438881935754,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 11134,
#        'yesterday_deaths': 1415,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 2397,
#        'yesterday_recovered': 7322,
#        'yesterday_total_hospitalised_patients': 432},
#       {'date': '2021-01-01',
#        'id': 'michoacan',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/michoacan',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Michoacán',
#        'name_es': 'Michoacán',
#        'name_it': 'Michoacán',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 33235,
#        'today_deaths': 2764,
#        'today_intensive_care': 41,
#        'today_new_confirmed': 101,
#        'today_new_deaths': 7,
#        'today_new_intensive_care': 41,
#        'today_new_open_cases': 94,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 7293,
#        'today_recovered': 23178,
#        'today_total_hospitalised_patients': 496,
#        'today_vs_yesterday_confirmed': 0.0030482284058670484,
#        'today_vs_yesterday_deaths': 0.0025389916575988547,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.013057369079038761,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 33134,
#        'yesterday_deaths': 2757,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 7199,
#        'yesterday_recovered': 23178,
#        'yesterday_total_hospitalised_patients': 496},
#       {'date': '2021-01-01',
#        'id': 'chihuahua',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/chihuahua',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Chihuahua',
#        'name_es': 'Chihuahua',
#        'name_it': 'Chihuahua',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 36517,
#        'today_deaths': 4440,
#        'today_intensive_care': 294,
#        'today_new_confirmed': 200,
#        'today_new_deaths': 27,
#        'today_new_intensive_care': 294,
#        'today_new_open_cases': 173,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 14760,
#        'today_recovered': 17317,
#        'today_total_hospitalised_patients': 956,
#        'today_vs_yesterday_confirmed': 0.005507062808051355,
#        'today_vs_yesterday_deaths': 0.00611828687967364,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.011859875231370332,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 36317,
#        'yesterday_deaths': 4413,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 14587,
#        'yesterday_recovered': 17317,
#        'yesterday_total_hospitalised_patients': 956},
#       {'date': '2021-01-01',
#        'id': 'yucatan',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/yucatan',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Yucatán',
#        'name_es': 'Yucatán',
#        'name_it': 'Yucatán',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 26748,
#        'today_deaths': 2323,
#        'today_intensive_care': 51,
#        'today_new_confirmed': 75,
#        'today_new_deaths': 32,
#        'today_new_intensive_care': 51,
#        'today_new_open_cases': 43,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 1,
#        'today_open_cases': 4903,
#        'today_recovered': 19522,
#        'today_total_hospitalised_patients': 524,
#        'today_vs_yesterday_confirmed': 0.0028118321898549237,
#        'today_vs_yesterday_deaths': 0.013967699694456659,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.008847736625514413,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0019120458891013214,
#        'yesterday_confirmed': 26673,
#        'yesterday_deaths': 2291,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 4860,
#        'yesterday_recovered': 19522,
#        'yesterday_total_hospitalised_patients': 523},
#       {'date': '2021-01-01',
#        'id': 'jalisco',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/jalisco',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Jalisco',
#        'name_es': 'Jalisco',
#        'name_it': 'Jalisco',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 52399,
#        'today_deaths': 6079,
#        'today_intensive_care': 80,
#        'today_new_confirmed': 405,
#        'today_new_deaths': 49,
#        'today_new_intensive_care': 80,
#        'today_new_open_cases': 356,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 16474,
#        'today_recovered': 29846,
#        'today_total_hospitalised_patients': 683,
#        'today_vs_yesterday_confirmed': 0.007789360310805016,
#        'today_vs_yesterday_deaths': 0.00812603648424548,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.02208710758158583,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 51994,
#        'yesterday_deaths': 6030,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 16118,
#        'yesterday_recovered': 29846,
#        'yesterday_total_hospitalised_patients': 683},
#       {'date': '2021-01-01',
#        'id': 'san_luis_potosi',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/san_luis_potosi',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'San Luis Potosí',
#        'name_es': 'San Luis Potosí',
#        'name_it': 'San Luis Potosí',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 39968,
#        'today_deaths': 3074,
#        'today_intensive_care': 30,
#        'today_new_confirmed': 99,
#        'today_new_deaths': 14,
#        'today_new_intensive_care': 30,
#        'today_new_open_cases': 85,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 9832,
#        'today_recovered': 27062,
#        'today_total_hospitalised_patients': 178,
#        'today_vs_yesterday_confirmed': 0.0024831322581453374,
#        'today_vs_yesterday_deaths': 0.004575163398692794,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.008720631989330041,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 39869,
#        'yesterday_deaths': 3060,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 9747,
#        'yesterday_recovered': 27062,
#        'yesterday_total_hospitalised_patients': 178},
#       {'date': '2021-01-01',
#        'id': 'campeche',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/campeche',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Campeche',
#        'name_es': 'Campeche',
#        'name_it': 'Campeche',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 7273,
#        'today_deaths': 972,
#        'today_intensive_care': 50,
#        'today_new_confirmed': 14,
#        'today_new_deaths': 3,
#        'today_new_intensive_care': 50,
#        'today_new_open_cases': 11,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 662,
#        'today_recovered': 5639,
#        'today_total_hospitalised_patients': 267,
#        'today_vs_yesterday_confirmed': 0.0019286403085825299,
#        'today_vs_yesterday_deaths': 0.003095975232198178,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.016897081413210335,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 7259,
#        'yesterday_deaths': 969,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 651,
#        'yesterday_recovered': 5639,
#        'yesterday_total_hospitalised_patients': 267},
#       {'date': '2021-01-01',
#        'id': 'sinaloa',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/sinaloa',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Sinaloa',
#        'name_es': 'Sinaloa',
#        'name_it': 'Sinaloa',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 26847,
#        'today_deaths': 4238,
#        'today_intensive_care': 157,
#        'today_new_confirmed': 76,
#        'today_new_deaths': 8,
#        'today_new_intensive_care': 157,
#        'today_new_open_cases': 68,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 4364,
#        'today_recovered': 18245,
#        'today_total_hospitalised_patients': 1652,
#        'today_vs_yesterday_confirmed': 0.002838892831795503,
#        'today_vs_yesterday_deaths': 0.001891252955082745,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.01582867783985109,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 26771,
#        'yesterday_deaths': 4230,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 4296,
#        'yesterday_recovered': 18245,
#        'yesterday_total_hospitalised_patients': 1652},
#       {'date': '2021-01-01',
#        'id': 'veracruz',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/veracruz',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Veracruz',
#        'name_es': 'Veracruz',
#        'name_it': 'Veracruz',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 43211,
#        'today_deaths': 6353,
#        'today_intensive_care': 258,
#        'today_new_confirmed': 83,
#        'today_new_deaths': 14,
#        'today_new_intensive_care': 258,
#        'today_new_open_cases': 69,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 4604,
#        'today_recovered': 32254,
#        'today_total_hospitalised_patients': 2219,
#        'today_vs_yesterday_confirmed': 0.0019245038026340922,
#        'today_vs_yesterday_deaths': 0.0022085502445181593,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.015214994487320777,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 43128,
#        'yesterday_deaths': 6339,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 4535,
#        'yesterday_recovered': 32254,
#        'yesterday_total_hospitalised_patients': 2219},
#       {'date': '2021-01-01',
#        'id': 'zacatecas',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/zacatecas',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Zacatecas',
#        'name_es': 'Zacatecas',
#        'name_it': 'Zacatecas',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 21203,
#        'today_deaths': 1771,
#        'today_intensive_care': 28,
#        'today_new_confirmed': 165,
#        'today_new_deaths': 12,
#        'today_new_intensive_care': 28,
#        'today_new_open_cases': 153,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 9525,
#        'today_recovered': 9907,
#        'today_total_hospitalised_patients': 114,
#        'today_vs_yesterday_confirmed': 0.007842950850841302,
#        'today_vs_yesterday_deaths': 0.006822057987492913,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.016325224071702893,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 21038,
#        'yesterday_deaths': 1759,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 9372,
#        'yesterday_recovered': 9907,
#        'yesterday_total_hospitalised_patients': 114},
#       {'date': '2021-01-01',
#        'id': 'tabasco',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/tabasco',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Tabasco',
#        'name_es': 'Tabasco',
#        'name_it': 'Tabasco',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 44592,
#        'today_deaths': 3207,
#        'today_intensive_care': 142,
#        'today_new_confirmed': 344,
#        'today_new_deaths': 7,
#        'today_new_intensive_care': 142,
#        'today_new_open_cases': 337,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 10021,
#        'today_recovered': 31364,
#        'today_total_hospitalised_patients': 1349,
#        'today_vs_yesterday_confirmed': 0.007774362683059088,
#        'today_vs_yesterday_deaths': 0.002187500000000009,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.03479966955803393,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 44248,
#        'yesterday_deaths': 3200,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 9684,
#        'yesterday_recovered': 31364,
#        'yesterday_total_hospitalised_patients': 1349},
#       {'date': '2021-01-01',
#        'id': 'queretaro',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/queretaro',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Querétaro',
#        'name_es': 'Querétaro',
#        'name_it': 'Querétaro',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 32582,
#        'today_deaths': 1890,
#        'today_intensive_care': 30,
#        'today_new_confirmed': 205,
#        'today_new_deaths': 5,
#        'today_new_intensive_care': 30,
#        'today_new_open_cases': 200,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 18209,
#        'today_recovered': 12483,
#        'today_total_hospitalised_patients': 449,
#        'today_vs_yesterday_confirmed': 0.006331655187324259,
#        'today_vs_yesterday_deaths': 0.0026525198938991412,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.011105558331945042,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 32377,
#        'yesterday_deaths': 1885,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 18009,
#        'yesterday_recovered': 12483,
#        'yesterday_total_hospitalised_patients': 449},
#       {'date': '2021-01-01',
#        'id': 'guanajuato',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/guanajuato',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Guanajuato',
#        'name_es': 'Guanajuato',
#        'name_it': 'Guanajuato',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 83520,
#        'today_deaths': 5365,
#        'today_intensive_care': 57,
#        'today_new_confirmed': 1003,
#        'today_new_deaths': 24,
#        'today_new_intensive_care': 57,
#        'today_new_open_cases': 979,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 32525,
#        'today_recovered': 45630,
#        'today_total_hospitalised_patients': 485,
#        'today_vs_yesterday_confirmed': 0.012155071076263013,
#        'today_vs_yesterday_deaths': 0.004493540535480234,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.03103404552082667,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 82517,
#        'yesterday_deaths': 5341,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 31546,
#        'yesterday_recovered': 45630,
#        'yesterday_total_hospitalised_patients': 485},
#       {'date': '2021-01-01',
#        'id': 'nuevo_leon',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/nuevo_leon',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Nuevo León',
#        'name_es': 'Nuevo León',
#        'name_it': 'Nuevo León',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 83209,
#        'today_deaths': 5202,
#        'today_intensive_care': 56,
#        'today_new_confirmed': 614,
#        'today_new_deaths': 31,
#        'today_new_intensive_care': 56,
#        'today_new_open_cases': 583,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 28978,
#        'today_recovered': 49029,
#        'today_total_hospitalised_patients': 347,
#        'today_vs_yesterday_confirmed': 0.007433864035353288,
#        'today_vs_yesterday_deaths': 0.005994971959002227,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.020531783764747402,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 82595,
#        'yesterday_deaths': 5171,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 28395,
#        'yesterday_recovered': 49029,
#        'yesterday_total_hospitalised_patients': 347},
#       {'date': '2021-01-01',
#        'id': 'aguascalientes',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/aguascalientes',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Aguascalientes',
#        'name_es': 'Aguascalientes',
#        'name_it': 'Aguascalientes',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 17021,
#        'today_deaths': 1371,
#        'today_intensive_care': 10,
#        'today_new_confirmed': 67,
#        'today_new_deaths': 2,
#        'today_new_intensive_care': 10,
#        'today_new_open_cases': 65,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 1,
#        'today_open_cases': 7200,
#        'today_recovered': 8450,
#        'today_total_hospitalised_patients': 213,
#        'today_vs_yesterday_confirmed': 0.003951869765247196,
#        'today_vs_yesterday_deaths': 0.0014609203798392478,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.009110021023125414,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.004716981132075526,
#        'yesterday_confirmed': 16954,
#        'yesterday_deaths': 1369,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 7135,
#        'yesterday_recovered': 8450,
#        'yesterday_total_hospitalised_patients': 212},
#       {'date': '2021-01-01',
#        'id': 'coahuila',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/coahuila',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Coahuila',
#        'name_es': 'Coahuila',
#        'name_it': 'Coahuila',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 49685,
#        'today_deaths': 4198,
#        'today_intensive_care': 12,
#        'today_new_confirmed': 258,
#        'today_new_deaths': 17,
#        'today_new_intensive_care': 12,
#        'today_new_open_cases': 241,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 14549,
#        'today_recovered': 30938,
#        'today_total_hospitalised_patients': 206,
#        'today_vs_yesterday_confirmed': 0.005219819127197711,
#        'today_vs_yesterday_deaths': 0.004066012915570516,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.016843723790886278,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 49427,
#        'yesterday_deaths': 4181,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 14308,
#        'yesterday_recovered': 30938,
#        'yesterday_total_hospitalised_patients': 206},
#       {'date': '2021-01-01',
#        'id': 'oaxaca',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/oaxaca',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Oaxaca',
#        'name_es': 'Oaxaca',
#        'name_it': 'Oaxaca',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 28404,
#        'today_deaths': 2130,
#        'today_intensive_care': 84,
#        'today_new_confirmed': 88,
#        'today_new_deaths': 4,
#        'today_new_intensive_care': 84,
#        'today_new_open_cases': 84,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 6724,
#        'today_recovered': 19550,
#        'today_total_hospitalised_patients': 522,
#        'today_vs_yesterday_confirmed': 0.0031077835852522107,
#        'today_vs_yesterday_deaths': 0.0018814675446847673,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.012650602409638445,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 28316,
#        'yesterday_deaths': 2126,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 6640,
#        'yesterday_recovered': 19550,
#        'yesterday_total_hospitalised_patients': 522},
#       {'date': '2021-01-01',
#        'id': 'estado_de_mexico',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/estado_de_mexico',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Estado de México',
#        'name_es': 'Estado de México',
#        'name_it': 'Estado de México',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 147443,
#        'today_deaths': 19017,
#        'today_intensive_care': 221,
#        'today_new_confirmed': 1244,
#        'today_new_deaths': 139,
#        'today_new_intensive_care': 221,
#        'today_new_open_cases': 1105,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 42021,
#        'today_recovered': 86405,
#        'today_total_hospitalised_patients': 6034,
#        'today_vs_yesterday_confirmed': 0.008508950129617832,
#        'today_vs_yesterday_deaths': 0.007363068121623018,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.027006550004888163,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 146199,
#        'yesterday_deaths': 18878,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 40916,
#        'yesterday_recovered': 86405,
#        'yesterday_total_hospitalised_patients': 6034},
#       {'date': '2021-01-01',
#        'id': 'colima',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/colima',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Colima',
#        'name_es': 'Colima',
#        'name_it': 'Colima',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 7949,
#        'today_deaths': 799,
#        'today_intensive_care': 6,
#        'today_new_confirmed': 22,
#        'today_new_deaths': 0,
#        'today_new_intensive_care': 6,
#        'today_new_open_cases': 22,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 1359,
#        'today_recovered': 5791,
#        'today_total_hospitalised_patients': 106,
#        'today_vs_yesterday_confirmed': 0.0027753248391573226,
#        'today_vs_yesterday_deaths': 0.0,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.01645474943904257,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 7927,
#        'yesterday_deaths': 799,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 1337,
#        'yesterday_recovered': 5791,
#        'yesterday_total_hospitalised_patients': 106},
#       {'date': '2021-01-01',
#        'id': 'nayarit',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/nayarit',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Nayarit',
#        'name_es': 'Nayarit',
#        'name_it': 'Nayarit',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 7922,
#        'today_deaths': 1053,
#        'today_intensive_care': 15,
#        'today_new_confirmed': 48,
#        'today_new_deaths': 3,
#        'today_new_intensive_care': 15,
#        'today_new_open_cases': 45,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 1124,
#        'today_recovered': 5745,
#        'today_total_hospitalised_patients': 234,
#        'today_vs_yesterday_confirmed': 0.00609601219202438,
#        'today_vs_yesterday_deaths': 0.0028571428571428914,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.0417052826691382,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 7874,
#        'yesterday_deaths': 1050,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 1079,
#        'yesterday_recovered': 5745,
#        'yesterday_total_hospitalised_patients': 234},
#       {'date': '2021-01-01',
#        'id': 'tamaulipas',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/tamaulipas',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Tamaulipas',
#        'name_es': 'Tamaulipas',
#        'name_it': 'Tamaulipas',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 39416,
#        'today_deaths': 3281,
#        'today_intensive_care': 24,
#        'today_new_confirmed': 29,
#        'today_new_deaths': 2,
#        'today_new_intensive_care': 24,
#        'today_new_open_cases': 27,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 6685,
#        'today_recovered': 29450,
#        'today_total_hospitalised_patients': 290,
#        'today_vs_yesterday_confirmed': 0.0007362835453321726,
#        'today_vs_yesterday_deaths': 0.0006099420555047974,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.004055271853409481,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 39387,
#        'yesterday_deaths': 3279,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 6658,
#        'yesterday_recovered': 29450,
#        'yesterday_total_hospitalised_patients': 290},
#       {'date': '2021-01-01',
#        'id': 'hidalgo',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/hidalgo',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Hidalgo',
#        'name_es': 'Hidalgo',
#        'name_it': 'Hidalgo',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 24599,
#        'today_deaths': 3429,
#        'today_intensive_care': 91,
#        'today_new_confirmed': 164,
#        'today_new_deaths': 11,
#        'today_new_intensive_care': 91,
#        'today_new_open_cases': 153,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 7800,
#        'today_recovered': 13370,
#        'today_total_hospitalised_patients': 903,
#        'today_vs_yesterday_confirmed': 0.006711684059750311,
#        'today_vs_yesterday_deaths': 0.0032182562902280942,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.020007846214201708,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 24435,
#        'yesterday_deaths': 3418,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 7647,
#        'yesterday_recovered': 13370,
#        'yesterday_total_hospitalised_patients': 903},
#       {'date': '2021-01-01',
#        'id': 'sonora',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/sonora',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Sonora',
#        'name_es': 'Sonora',
#        'name_it': 'Sonora',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 52146,
#        'today_deaths': 4196,
#        'today_intensive_care': 46,
#        'today_new_confirmed': 438,
#        'today_new_deaths': 35,
#        'today_new_intensive_care': 46,
#        'today_new_open_cases': 403,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 12924,
#        'today_recovered': 35026,
#        'today_total_hospitalised_patients': 585,
#        'today_vs_yesterday_confirmed': 0.008470642840566311,
#        'today_vs_yesterday_deaths': 0.00841143955779855,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.03218592764156214,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 51708,
#        'yesterday_deaths': 4161,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 12521,
#        'yesterday_recovered': 35026,
#        'yesterday_total_hospitalised_patients': 585},
#       {'date': '2021-01-01',
#        'id': 'chiapas',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/chiapas',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Chiapas',
#        'name_es': 'Chiapas',
#        'name_it': 'Chiapas',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 8293,
#        'today_deaths': 1206,
#        'today_intensive_care': 92,
#        'today_new_confirmed': 6,
#        'today_new_deaths': 5,
#        'today_new_intensive_care': 92,
#        'today_new_open_cases': 1,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 649,
#        'today_recovered': 6438,
#        'today_total_hospitalised_patients': 630,
#        'today_vs_yesterday_confirmed': 0.0007240255822371644,
#        'today_vs_yesterday_deaths': 0.004163197335553814,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.0015432098765431057,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 8287,
#        'yesterday_deaths': 1201,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 648,
#        'yesterday_recovered': 6438,
#        'yesterday_total_hospitalised_patients': 630},
#       {'date': '2021-01-01',
#        'id': 'durango',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/durango',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Durango',
#        'name_es': 'Durango',
#        'name_it': 'Durango',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 25248,
#        'today_deaths': 1555,
#        'today_intensive_care': 15,
#        'today_new_confirmed': 181,
#        'today_new_deaths': 11,
#        'today_new_intensive_care': 15,
#        'today_new_open_cases': 170,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 10467,
#        'today_recovered': 13226,
#        'today_total_hospitalised_patients': 146,
#        'today_vs_yesterday_confirmed': 0.0072206486615868926,
#        'today_vs_yesterday_deaths': 0.007124352331606243,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.016509663008643205,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 25067,
#        'yesterday_deaths': 1544,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 10297,
#        'yesterday_recovered': 13226,
#        'yesterday_total_hospitalised_patients': 146},
#       {'date': '2021-01-01',
#        'id': 'puebla',
#        'links': [{'href': '/api/2021-01-01/country/mexico/region/puebla',
#          'rel': 'self',
#          'type': 'GET'}],
#        'name': 'Puebla',
#        'name_es': 'Puebla',
#        'name_it': 'Puebla',
#        'source': 'Secretaría de Salud México',
#        'sub_regions': [],
#        'today_confirmed': 47636,
#        'today_deaths': 5755,
#        'today_intensive_care': 199,
#        'today_new_confirmed': 353,
#        'today_new_deaths': 45,
#        'today_new_intensive_care': 199,
#        'today_new_open_cases': 308,
#        'today_new_recovered': 0,
#        'today_new_total_hospitalised_patients': 0,
#        'today_open_cases': 11170,
#        'today_recovered': 30711,
#        'today_total_hospitalised_patients': 1676,
#        'today_vs_yesterday_confirmed': 0.007465685341454753,
#        'today_vs_yesterday_deaths': 0.007880910683012221,
#        'today_vs_yesterday_intensive_care': None,
#        'today_vs_yesterday_open_cases': 0.02835573559197191,
#        'today_vs_yesterday_recovered': 0.0,
#        'today_vs_yesterday_total_hospitalised_patients': 0.0,
#        'yesterday_confirmed': 47283,
#        'yesterday_deaths': 5710,
#        'yesterday_intensive_care': 0,
#        'yesterday_open_cases': 10862,
#        'yesterday_recovered': 30711,
#        'yesterday_total_hospitalised_patients': 1676}],
#      'source': 'Secretaría de Salud México',
#      'today_confirmed': 1437185,
#      'today_deaths': 126507,
#      'today_intensive_care': 3501,
#      'today_new_confirmed': 11091,
#      'today_new_deaths': 700,
#      'today_new_intensive_care': 3501,
#      'today_new_open_cases': 1418,
#      'today_new_recovered': 8973,
#      'today_new_total_hospitalised_patients': 3,
#      'today_open_cases': 226910,
#      'today_recovered': 1083768,
#      'today_total_hospitalised_patients': 37437,
#      'today_vs_yesterday_confirmed': 0.007777187198038771,
#      'today_vs_yesterday_deaths': 0.005564078310427822,
#      'today_vs_yesterday_intensive_care': None,
#      'today_vs_yesterday_open_cases': 0.006288471431358911,
#      'today_vs_yesterday_recovered': 0.008348568796840317,
#      'today_vs_yesterday_total_hospitalised_patients': 8.014104824494162e-05,
#      'yesterday_confirmed': 1426094,
#      'yesterday_deaths': 125807,
#      'yesterday_intensive_care': 0,
#      'yesterday_open_cases': 225492,
#      'yesterday_recovered': 1074795,
#      'yesterday_total_hospitalised_patients': 37434}},
#    'info': {'date': '2021-01-01 00:00CET',
#     'date_generation': '2021-01-03 23:50',
#     'yesterday': '2020-12-31 00:00CET'}}},
#  'metadata': {'by': 'Narrativa & AppliedXL',
#   'url': ['wwww.narrativa.com', 'www.appliedxl.com']},
#  'total': {'date': '2021-01-01',
#   'name': 'Total',
#   'name_es': 'Total',
#   'name_it': 'Total',
#   'rid': '#total',
#   'source': 'Narrativa',
#   'today_confirmed': 83899932,
#   'today_deaths': 1826966,
#   'today_new_confirmed': 540079,
#   'today_new_deaths': 9420,
#   'today_new_open_cases': -174859,
#   'today_new_recovered': 705518,
#   'today_open_cases': 26560773,
#   'today_recovered': 55512193,
#   'today_vs_yesterday_confirmed': 0.006478886185175892,
#   'today_vs_yesterday_deaths': 0.005182812429506578,
#   'today_vs_yesterday_open_cases': -0.006540297981360577,
#   'today_vs_yesterday_recovered': 0.012872848060934139,
#   'yesterday_confirmed': 83359853,
#   'yesterday_deaths': 1817546,
#   'yesterday_open_cases': 26735632,
#   'yesterday_recovered': 54806675},
#  'updated_at': '2021-01-03 22:50UTC'}

# %% [markdown]
# Trataremos de mejorar la presentación para que sea más entendible

# %%
import json
print(json.dumps(data_days[0], sort_keys=True, indent=3))
# Out:
# {
#    "dates": {
#       "2021-01-01": {
#          "countries": {
#             "Mexico": {
#                "date": "2021-01-01",
#                "id": "mexico",
#                "links": [
#                   {
#                      "href": "/api/2021-01-01/country/mexico",
#                      "rel": "self",
#                      "type": "GET"
#                   }
#                ],
#                "name": "Mexico",
#                "name_es": "M\u00e9xico",
#                "name_it": "Messico",
#                "regions": [
#                   {
#                      "date": "2021-01-01",
#                      "id": "morelos",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/morelos",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Morelos",
#                      "name_es": "Morelos",
#                      "name_it": "Morelos",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 9930,
#                      "today_deaths": 1456,
#                      "today_intensive_care": 49,
#                      "today_new_confirmed": 112,
#                      "today_new_deaths": 9,
#                      "today_new_intensive_care": 49,
#                      "today_new_open_cases": 103,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 2843,
#                      "today_recovered": 5631,
#                      "today_total_hospitalised_patients": 795,
#                      "today_vs_yesterday_confirmed": 0.011407618659604823,
#                      "today_vs_yesterday_deaths": 0.0062197650310988895,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.03759124087591248,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 9818,
#                      "yesterday_deaths": 1447,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 2740,
#                      "yesterday_recovered": 5631,
#                      "yesterday_total_hospitalised_patients": 795
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "guerrero",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/guerrero",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Guerrero",
#                      "name_es": "Guerrero",
#                      "name_it": "Guerrero",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 26024,
#                      "today_deaths": 2716,
#                      "today_intensive_care": 115,
#                      "today_new_confirmed": 50,
#                      "today_new_deaths": 13,
#                      "today_new_intensive_care": 115,
#                      "today_new_open_cases": 37,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 3299,
#                      "today_recovered": 20009,
#                      "today_total_hospitalised_patients": 807,
#                      "today_vs_yesterday_confirmed": 0.0019250019250018902,
#                      "today_vs_yesterday_deaths": 0.004809470958194506,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.01134273451870027,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 25974,
#                      "yesterday_deaths": 2703,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 3262,
#                      "yesterday_recovered": 20009,
#                      "yesterday_total_hospitalised_patients": 807
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "baja_california_sur",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/baja_california_sur",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Baja California Sur",
#                      "name_es": "Baja California Sur",
#                      "name_it": "Baja California Sur",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 17820,
#                      "today_deaths": 784,
#                      "today_intensive_care": 11,
#                      "today_new_confirmed": 141,
#                      "today_new_deaths": 9,
#                      "today_new_intensive_care": 11,
#                      "today_new_open_cases": 132,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 5135,
#                      "today_recovered": 11901,
#                      "today_total_hospitalised_patients": 122,
#                      "today_vs_yesterday_confirmed": 0.007975564228746013,
#                      "today_vs_yesterday_deaths": 0.011612903225806548,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.026384169498300913,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 17679,
#                      "yesterday_deaths": 775,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 5003,
#                      "yesterday_recovered": 11901,
#                      "yesterday_total_hospitalised_patients": 122
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "ciudad_de_mexico",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/ciudad_de_mexico",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Ciudad de M\u00e9xico",
#                      "name_es": "Ciudad de M\u00e9xico",
#                      "name_it": "Ciudad de M\u00e9xico",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 334137,
#                      "today_deaths": 16873,
#                      "today_intensive_care": 916,
#                      "today_new_confirmed": 3864,
#                      "today_new_deaths": 119,
#                      "today_new_intensive_care": 916,
#                      "today_new_open_cases": 3745,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 1,
#                      "today_open_cases": 174936,
#                      "today_recovered": 142328,
#                      "today_total_hospitalised_patients": 10333,
#                      "today_vs_yesterday_confirmed": 0.01169941230436633,
#                      "today_vs_yesterday_deaths": 0.007102781425331273,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.02187615003125165,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 9.678668215262753e-05,
#                      "yesterday_confirmed": 330273,
#                      "yesterday_deaths": 16754,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 171191,
#                      "yesterday_recovered": 142328,
#                      "yesterday_total_hospitalised_patients": 10332
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "baja_california",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/baja_california",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Baja California",
#                      "name_es": "Baja California",
#                      "name_it": "Baja California",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 34889,
#                      "today_deaths": 5559,
#                      "today_intensive_care": 59,
#                      "today_new_confirmed": 312,
#                      "today_new_deaths": 35,
#                      "today_new_intensive_care": 59,
#                      "today_new_open_cases": 277,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 10415,
#                      "today_recovered": 18915,
#                      "today_total_hospitalised_patients": 2755,
#                      "today_vs_yesterday_confirmed": 0.009023339213928283,
#                      "today_vs_yesterday_deaths": 0.006335988414192695,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.02732294338133756,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 34577,
#                      "yesterday_deaths": 5524,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 10138,
#                      "yesterday_recovered": 18915,
#                      "yesterday_total_hospitalised_patients": 2755
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "quintana_roo",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/quintana_roo",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Quintana Roo",
#                      "name_es": "Quintana Roo",
#                      "name_it": "Quintana Roo",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 15968,
#                      "today_deaths": 2031,
#                      "today_intensive_care": 151,
#                      "today_new_confirmed": 113,
#                      "today_new_deaths": 3,
#                      "today_new_intensive_care": 151,
#                      "today_new_open_cases": 110,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 2264,
#                      "today_recovered": 11673,
#                      "today_total_hospitalised_patients": 929,
#                      "today_vs_yesterday_confirmed": 0.00712708924629446,
#                      "today_vs_yesterday_deaths": 0.0014792899408284654,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.05106778087279484,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 15855,
#                      "yesterday_deaths": 2028,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 2154,
#                      "yesterday_recovered": 11673,
#                      "yesterday_total_hospitalised_patients": 929
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "tlaxcala",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/tlaxcala",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Tlaxcala",
#                      "name_es": "Tlaxcala",
#                      "name_it": "Tlaxcala",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 11351,
#                      "today_deaths": 1420,
#                      "today_intensive_care": 111,
#                      "today_new_confirmed": 217,
#                      "today_new_deaths": 5,
#                      "today_new_intensive_care": 111,
#                      "today_new_open_cases": 212,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 2609,
#                      "today_recovered": 7322,
#                      "today_total_hospitalised_patients": 432,
#                      "today_vs_yesterday_confirmed": 0.01948985090713129,
#                      "today_vs_yesterday_deaths": 0.0035335689045936647,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.0884438881935754,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 11134,
#                      "yesterday_deaths": 1415,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 2397,
#                      "yesterday_recovered": 7322,
#                      "yesterday_total_hospitalised_patients": 432
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "michoacan",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/michoacan",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Michoac\u00e1n",
#                      "name_es": "Michoac\u00e1n",
#                      "name_it": "Michoac\u00e1n",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 33235,
#                      "today_deaths": 2764,
#                      "today_intensive_care": 41,
#                      "today_new_confirmed": 101,
#                      "today_new_deaths": 7,
#                      "today_new_intensive_care": 41,
#                      "today_new_open_cases": 94,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 7293,
#                      "today_recovered": 23178,
#                      "today_total_hospitalised_patients": 496,
#                      "today_vs_yesterday_confirmed": 0.0030482284058670484,
#                      "today_vs_yesterday_deaths": 0.0025389916575988547,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.013057369079038761,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 33134,
#                      "yesterday_deaths": 2757,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 7199,
#                      "yesterday_recovered": 23178,
#                      "yesterday_total_hospitalised_patients": 496
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "chihuahua",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/chihuahua",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Chihuahua",
#                      "name_es": "Chihuahua",
#                      "name_it": "Chihuahua",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 36517,
#                      "today_deaths": 4440,
#                      "today_intensive_care": 294,
#                      "today_new_confirmed": 200,
#                      "today_new_deaths": 27,
#                      "today_new_intensive_care": 294,
#                      "today_new_open_cases": 173,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 14760,
#                      "today_recovered": 17317,
#                      "today_total_hospitalised_patients": 956,
#                      "today_vs_yesterday_confirmed": 0.005507062808051355,
#                      "today_vs_yesterday_deaths": 0.00611828687967364,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.011859875231370332,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 36317,
#                      "yesterday_deaths": 4413,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 14587,
#                      "yesterday_recovered": 17317,
#                      "yesterday_total_hospitalised_patients": 956
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "yucatan",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/yucatan",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Yucat\u00e1n",
#                      "name_es": "Yucat\u00e1n",
#                      "name_it": "Yucat\u00e1n",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 26748,
#                      "today_deaths": 2323,
#                      "today_intensive_care": 51,
#                      "today_new_confirmed": 75,
#                      "today_new_deaths": 32,
#                      "today_new_intensive_care": 51,
#                      "today_new_open_cases": 43,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 1,
#                      "today_open_cases": 4903,
#                      "today_recovered": 19522,
#                      "today_total_hospitalised_patients": 524,
#                      "today_vs_yesterday_confirmed": 0.0028118321898549237,
#                      "today_vs_yesterday_deaths": 0.013967699694456659,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.008847736625514413,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0019120458891013214,
#                      "yesterday_confirmed": 26673,
#                      "yesterday_deaths": 2291,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 4860,
#                      "yesterday_recovered": 19522,
#                      "yesterday_total_hospitalised_patients": 523
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "jalisco",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/jalisco",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Jalisco",
#                      "name_es": "Jalisco",
#                      "name_it": "Jalisco",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 52399,
#                      "today_deaths": 6079,
#                      "today_intensive_care": 80,
#                      "today_new_confirmed": 405,
#                      "today_new_deaths": 49,
#                      "today_new_intensive_care": 80,
#                      "today_new_open_cases": 356,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 16474,
#                      "today_recovered": 29846,
#                      "today_total_hospitalised_patients": 683,
#                      "today_vs_yesterday_confirmed": 0.007789360310805016,
#                      "today_vs_yesterday_deaths": 0.00812603648424548,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.02208710758158583,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 51994,
#                      "yesterday_deaths": 6030,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 16118,
#                      "yesterday_recovered": 29846,
#                      "yesterday_total_hospitalised_patients": 683
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "san_luis_potosi",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/san_luis_potosi",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "San Luis Potos\u00ed",
#                      "name_es": "San Luis Potos\u00ed",
#                      "name_it": "San Luis Potos\u00ed",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 39968,
#                      "today_deaths": 3074,
#                      "today_intensive_care": 30,
#                      "today_new_confirmed": 99,
#                      "today_new_deaths": 14,
#                      "today_new_intensive_care": 30,
#                      "today_new_open_cases": 85,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 9832,
#                      "today_recovered": 27062,
#                      "today_total_hospitalised_patients": 178,
#                      "today_vs_yesterday_confirmed": 0.0024831322581453374,
#                      "today_vs_yesterday_deaths": 0.004575163398692794,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.008720631989330041,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 39869,
#                      "yesterday_deaths": 3060,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 9747,
#                      "yesterday_recovered": 27062,
#                      "yesterday_total_hospitalised_patients": 178
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "campeche",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/campeche",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Campeche",
#                      "name_es": "Campeche",
#                      "name_it": "Campeche",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 7273,
#                      "today_deaths": 972,
#                      "today_intensive_care": 50,
#                      "today_new_confirmed": 14,
#                      "today_new_deaths": 3,
#                      "today_new_intensive_care": 50,
#                      "today_new_open_cases": 11,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 662,
#                      "today_recovered": 5639,
#                      "today_total_hospitalised_patients": 267,
#                      "today_vs_yesterday_confirmed": 0.0019286403085825299,
#                      "today_vs_yesterday_deaths": 0.003095975232198178,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.016897081413210335,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 7259,
#                      "yesterday_deaths": 969,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 651,
#                      "yesterday_recovered": 5639,
#                      "yesterday_total_hospitalised_patients": 267
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "sinaloa",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/sinaloa",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Sinaloa",
#                      "name_es": "Sinaloa",
#                      "name_it": "Sinaloa",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 26847,
#                      "today_deaths": 4238,
#                      "today_intensive_care": 157,
#                      "today_new_confirmed": 76,
#                      "today_new_deaths": 8,
#                      "today_new_intensive_care": 157,
#                      "today_new_open_cases": 68,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 4364,
#                      "today_recovered": 18245,
#                      "today_total_hospitalised_patients": 1652,
#                      "today_vs_yesterday_confirmed": 0.002838892831795503,
#                      "today_vs_yesterday_deaths": 0.001891252955082745,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.01582867783985109,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 26771,
#                      "yesterday_deaths": 4230,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 4296,
#                      "yesterday_recovered": 18245,
#                      "yesterday_total_hospitalised_patients": 1652
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "veracruz",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/veracruz",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Veracruz",
#                      "name_es": "Veracruz",
#                      "name_it": "Veracruz",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 43211,
#                      "today_deaths": 6353,
#                      "today_intensive_care": 258,
#                      "today_new_confirmed": 83,
#                      "today_new_deaths": 14,
#                      "today_new_intensive_care": 258,
#                      "today_new_open_cases": 69,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 4604,
#                      "today_recovered": 32254,
#                      "today_total_hospitalised_patients": 2219,
#                      "today_vs_yesterday_confirmed": 0.0019245038026340922,
#                      "today_vs_yesterday_deaths": 0.0022085502445181593,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.015214994487320777,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 43128,
#                      "yesterday_deaths": 6339,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 4535,
#                      "yesterday_recovered": 32254,
#                      "yesterday_total_hospitalised_patients": 2219
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "zacatecas",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/zacatecas",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Zacatecas",
#                      "name_es": "Zacatecas",
#                      "name_it": "Zacatecas",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 21203,
#                      "today_deaths": 1771,
#                      "today_intensive_care": 28,
#                      "today_new_confirmed": 165,
#                      "today_new_deaths": 12,
#                      "today_new_intensive_care": 28,
#                      "today_new_open_cases": 153,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 9525,
#                      "today_recovered": 9907,
#                      "today_total_hospitalised_patients": 114,
#                      "today_vs_yesterday_confirmed": 0.007842950850841302,
#                      "today_vs_yesterday_deaths": 0.006822057987492913,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.016325224071702893,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 21038,
#                      "yesterday_deaths": 1759,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 9372,
#                      "yesterday_recovered": 9907,
#                      "yesterday_total_hospitalised_patients": 114
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "tabasco",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/tabasco",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Tabasco",
#                      "name_es": "Tabasco",
#                      "name_it": "Tabasco",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 44592,
#                      "today_deaths": 3207,
#                      "today_intensive_care": 142,
#                      "today_new_confirmed": 344,
#                      "today_new_deaths": 7,
#                      "today_new_intensive_care": 142,
#                      "today_new_open_cases": 337,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 10021,
#                      "today_recovered": 31364,
#                      "today_total_hospitalised_patients": 1349,
#                      "today_vs_yesterday_confirmed": 0.007774362683059088,
#                      "today_vs_yesterday_deaths": 0.002187500000000009,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.03479966955803393,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 44248,
#                      "yesterday_deaths": 3200,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 9684,
#                      "yesterday_recovered": 31364,
#                      "yesterday_total_hospitalised_patients": 1349
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "queretaro",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/queretaro",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Quer\u00e9taro",
#                      "name_es": "Quer\u00e9taro",
#                      "name_it": "Quer\u00e9taro",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 32582,
#                      "today_deaths": 1890,
#                      "today_intensive_care": 30,
#                      "today_new_confirmed": 205,
#                      "today_new_deaths": 5,
#                      "today_new_intensive_care": 30,
#                      "today_new_open_cases": 200,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 18209,
#                      "today_recovered": 12483,
#                      "today_total_hospitalised_patients": 449,
#                      "today_vs_yesterday_confirmed": 0.006331655187324259,
#                      "today_vs_yesterday_deaths": 0.0026525198938991412,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.011105558331945042,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 32377,
#                      "yesterday_deaths": 1885,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 18009,
#                      "yesterday_recovered": 12483,
#                      "yesterday_total_hospitalised_patients": 449
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "guanajuato",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/guanajuato",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Guanajuato",
#                      "name_es": "Guanajuato",
#                      "name_it": "Guanajuato",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 83520,
#                      "today_deaths": 5365,
#                      "today_intensive_care": 57,
#                      "today_new_confirmed": 1003,
#                      "today_new_deaths": 24,
#                      "today_new_intensive_care": 57,
#                      "today_new_open_cases": 979,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 32525,
#                      "today_recovered": 45630,
#                      "today_total_hospitalised_patients": 485,
#                      "today_vs_yesterday_confirmed": 0.012155071076263013,
#                      "today_vs_yesterday_deaths": 0.004493540535480234,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.03103404552082667,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 82517,
#                      "yesterday_deaths": 5341,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 31546,
#                      "yesterday_recovered": 45630,
#                      "yesterday_total_hospitalised_patients": 485
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "nuevo_leon",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/nuevo_leon",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Nuevo Le\u00f3n",
#                      "name_es": "Nuevo Le\u00f3n",
#                      "name_it": "Nuevo Le\u00f3n",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 83209,
#                      "today_deaths": 5202,
#                      "today_intensive_care": 56,
#                      "today_new_confirmed": 614,
#                      "today_new_deaths": 31,
#                      "today_new_intensive_care": 56,
#                      "today_new_open_cases": 583,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 28978,
#                      "today_recovered": 49029,
#                      "today_total_hospitalised_patients": 347,
#                      "today_vs_yesterday_confirmed": 0.007433864035353288,
#                      "today_vs_yesterday_deaths": 0.005994971959002227,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.020531783764747402,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 82595,
#                      "yesterday_deaths": 5171,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 28395,
#                      "yesterday_recovered": 49029,
#                      "yesterday_total_hospitalised_patients": 347
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "aguascalientes",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/aguascalientes",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Aguascalientes",
#                      "name_es": "Aguascalientes",
#                      "name_it": "Aguascalientes",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 17021,
#                      "today_deaths": 1371,
#                      "today_intensive_care": 10,
#                      "today_new_confirmed": 67,
#                      "today_new_deaths": 2,
#                      "today_new_intensive_care": 10,
#                      "today_new_open_cases": 65,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 1,
#                      "today_open_cases": 7200,
#                      "today_recovered": 8450,
#                      "today_total_hospitalised_patients": 213,
#                      "today_vs_yesterday_confirmed": 0.003951869765247196,
#                      "today_vs_yesterday_deaths": 0.0014609203798392478,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.009110021023125414,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.004716981132075526,
#                      "yesterday_confirmed": 16954,
#                      "yesterday_deaths": 1369,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 7135,
#                      "yesterday_recovered": 8450,
#                      "yesterday_total_hospitalised_patients": 212
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "coahuila",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/coahuila",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Coahuila",
#                      "name_es": "Coahuila",
#                      "name_it": "Coahuila",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 49685,
#                      "today_deaths": 4198,
#                      "today_intensive_care": 12,
#                      "today_new_confirmed": 258,
#                      "today_new_deaths": 17,
#                      "today_new_intensive_care": 12,
#                      "today_new_open_cases": 241,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 14549,
#                      "today_recovered": 30938,
#                      "today_total_hospitalised_patients": 206,
#                      "today_vs_yesterday_confirmed": 0.005219819127197711,
#                      "today_vs_yesterday_deaths": 0.004066012915570516,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.016843723790886278,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 49427,
#                      "yesterday_deaths": 4181,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 14308,
#                      "yesterday_recovered": 30938,
#                      "yesterday_total_hospitalised_patients": 206
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "oaxaca",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/oaxaca",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Oaxaca",
#                      "name_es": "Oaxaca",
#                      "name_it": "Oaxaca",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 28404,
#                      "today_deaths": 2130,
#                      "today_intensive_care": 84,
#                      "today_new_confirmed": 88,
#                      "today_new_deaths": 4,
#                      "today_new_intensive_care": 84,
#                      "today_new_open_cases": 84,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 6724,
#                      "today_recovered": 19550,
#                      "today_total_hospitalised_patients": 522,
#                      "today_vs_yesterday_confirmed": 0.0031077835852522107,
#                      "today_vs_yesterday_deaths": 0.0018814675446847673,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.012650602409638445,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 28316,
#                      "yesterday_deaths": 2126,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 6640,
#                      "yesterday_recovered": 19550,
#                      "yesterday_total_hospitalised_patients": 522
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "estado_de_mexico",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/estado_de_mexico",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Estado de M\u00e9xico",
#                      "name_es": "Estado de M\u00e9xico",
#                      "name_it": "Estado de M\u00e9xico",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 147443,
#                      "today_deaths": 19017,
#                      "today_intensive_care": 221,
#                      "today_new_confirmed": 1244,
#                      "today_new_deaths": 139,
#                      "today_new_intensive_care": 221,
#                      "today_new_open_cases": 1105,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 42021,
#                      "today_recovered": 86405,
#                      "today_total_hospitalised_patients": 6034,
#                      "today_vs_yesterday_confirmed": 0.008508950129617832,
#                      "today_vs_yesterday_deaths": 0.007363068121623018,
#                      "today_vs_yesterday_intensive_care": null,
# ...
#                      "name_it": "Nayarit",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 7922,
#                      "today_deaths": 1053,
#                      "today_intensive_care": 15,
#                      "today_new_confirmed": 48,
#                      "today_new_deaths": 3,
#                      "today_new_intensive_care": 15,
#                      "today_new_open_cases": 45,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 1124,
#                      "today_recovered": 5745,
#                      "today_total_hospitalised_patients": 234,
#                      "today_vs_yesterday_confirmed": 0.00609601219202438,
#                      "today_vs_yesterday_deaths": 0.0028571428571428914,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.0417052826691382,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 7874,
#                      "yesterday_deaths": 1050,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 1079,
#                      "yesterday_recovered": 5745,
#                      "yesterday_total_hospitalised_patients": 234
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "tamaulipas",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/tamaulipas",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Tamaulipas",
#                      "name_es": "Tamaulipas",
#                      "name_it": "Tamaulipas",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 39416,
#                      "today_deaths": 3281,
#                      "today_intensive_care": 24,
#                      "today_new_confirmed": 29,
#                      "today_new_deaths": 2,
#                      "today_new_intensive_care": 24,
#                      "today_new_open_cases": 27,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 6685,
#                      "today_recovered": 29450,
#                      "today_total_hospitalised_patients": 290,
#                      "today_vs_yesterday_confirmed": 0.0007362835453321726,
#                      "today_vs_yesterday_deaths": 0.0006099420555047974,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.004055271853409481,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 39387,
#                      "yesterday_deaths": 3279,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 6658,
#                      "yesterday_recovered": 29450,
#                      "yesterday_total_hospitalised_patients": 290
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "hidalgo",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/hidalgo",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Hidalgo",
#                      "name_es": "Hidalgo",
#                      "name_it": "Hidalgo",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 24599,
#                      "today_deaths": 3429,
#                      "today_intensive_care": 91,
#                      "today_new_confirmed": 164,
#                      "today_new_deaths": 11,
#                      "today_new_intensive_care": 91,
#                      "today_new_open_cases": 153,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 7800,
#                      "today_recovered": 13370,
#                      "today_total_hospitalised_patients": 903,
#                      "today_vs_yesterday_confirmed": 0.006711684059750311,
#                      "today_vs_yesterday_deaths": 0.0032182562902280942,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.020007846214201708,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 24435,
#                      "yesterday_deaths": 3418,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 7647,
#                      "yesterday_recovered": 13370,
#                      "yesterday_total_hospitalised_patients": 903
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "sonora",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/sonora",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Sonora",
#                      "name_es": "Sonora",
#                      "name_it": "Sonora",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 52146,
#                      "today_deaths": 4196,
#                      "today_intensive_care": 46,
#                      "today_new_confirmed": 438,
#                      "today_new_deaths": 35,
#                      "today_new_intensive_care": 46,
#                      "today_new_open_cases": 403,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 12924,
#                      "today_recovered": 35026,
#                      "today_total_hospitalised_patients": 585,
#                      "today_vs_yesterday_confirmed": 0.008470642840566311,
#                      "today_vs_yesterday_deaths": 0.00841143955779855,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.03218592764156214,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 51708,
#                      "yesterday_deaths": 4161,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 12521,
#                      "yesterday_recovered": 35026,
#                      "yesterday_total_hospitalised_patients": 585
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "chiapas",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/chiapas",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Chiapas",
#                      "name_es": "Chiapas",
#                      "name_it": "Chiapas",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 8293,
#                      "today_deaths": 1206,
#                      "today_intensive_care": 92,
#                      "today_new_confirmed": 6,
#                      "today_new_deaths": 5,
#                      "today_new_intensive_care": 92,
#                      "today_new_open_cases": 1,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 649,
#                      "today_recovered": 6438,
#                      "today_total_hospitalised_patients": 630,
#                      "today_vs_yesterday_confirmed": 0.0007240255822371644,
#                      "today_vs_yesterday_deaths": 0.004163197335553814,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.0015432098765431057,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 8287,
#                      "yesterday_deaths": 1201,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 648,
#                      "yesterday_recovered": 6438,
#                      "yesterday_total_hospitalised_patients": 630
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "durango",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/durango",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Durango",
#                      "name_es": "Durango",
#                      "name_it": "Durango",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 25248,
#                      "today_deaths": 1555,
#                      "today_intensive_care": 15,
#                      "today_new_confirmed": 181,
#                      "today_new_deaths": 11,
#                      "today_new_intensive_care": 15,
#                      "today_new_open_cases": 170,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 10467,
#                      "today_recovered": 13226,
#                      "today_total_hospitalised_patients": 146,
#                      "today_vs_yesterday_confirmed": 0.0072206486615868926,
#                      "today_vs_yesterday_deaths": 0.007124352331606243,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.016509663008643205,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 25067,
#                      "yesterday_deaths": 1544,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 10297,
#                      "yesterday_recovered": 13226,
#                      "yesterday_total_hospitalised_patients": 146
#                   },
#                   {
#                      "date": "2021-01-01",
#                      "id": "puebla",
#                      "links": [
#                         {
#                            "href": "/api/2021-01-01/country/mexico/region/puebla",
#                            "rel": "self",
#                            "type": "GET"
#                         }
#                      ],
#                      "name": "Puebla",
#                      "name_es": "Puebla",
#                      "name_it": "Puebla",
#                      "source": "Secretar\u00eda de Salud M\u00e9xico",
#                      "sub_regions": [],
#                      "today_confirmed": 47636,
#                      "today_deaths": 5755,
#                      "today_intensive_care": 199,
#                      "today_new_confirmed": 353,
#                      "today_new_deaths": 45,
#                      "today_new_intensive_care": 199,
#                      "today_new_open_cases": 308,
#                      "today_new_recovered": 0,
#                      "today_new_total_hospitalised_patients": 0,
#                      "today_open_cases": 11170,
#                      "today_recovered": 30711,
#                      "today_total_hospitalised_patients": 1676,
#                      "today_vs_yesterday_confirmed": 0.007465685341454753,
#                      "today_vs_yesterday_deaths": 0.007880910683012221,
#                      "today_vs_yesterday_intensive_care": null,
#                      "today_vs_yesterday_open_cases": 0.02835573559197191,
#                      "today_vs_yesterday_recovered": 0.0,
#                      "today_vs_yesterday_total_hospitalised_patients": 0.0,
#                      "yesterday_confirmed": 47283,
#                      "yesterday_deaths": 5710,
#                      "yesterday_intensive_care": 0,
#                      "yesterday_open_cases": 10862,
#                      "yesterday_recovered": 30711,
#                      "yesterday_total_hospitalised_patients": 1676
#                   }
#                ],
#                "source": "Secretar\u00eda de Salud M\u00e9xico",
#                "today_confirmed": 1437185,
#                "today_deaths": 126507,
#                "today_intensive_care": 3501,
#                "today_new_confirmed": 11091,
#                "today_new_deaths": 700,
#                "today_new_intensive_care": 3501,
#                "today_new_open_cases": 1418,
#                "today_new_recovered": 8973,
#                "today_new_total_hospitalised_patients": 3,
#                "today_open_cases": 226910,
#                "today_recovered": 1083768,
#                "today_total_hospitalised_patients": 37437,
#                "today_vs_yesterday_confirmed": 0.007777187198038771,
#                "today_vs_yesterday_deaths": 0.005564078310427822,
#                "today_vs_yesterday_intensive_care": null,
#                "today_vs_yesterday_open_cases": 0.006288471431358911,
#                "today_vs_yesterday_recovered": 0.008348568796840317,
#                "today_vs_yesterday_total_hospitalised_patients": 8.014104824494162e-05,
#                "yesterday_confirmed": 1426094,
#                "yesterday_deaths": 125807,
#                "yesterday_intensive_care": 0,
#                "yesterday_open_cases": 225492,
#                "yesterday_recovered": 1074795,
#                "yesterday_total_hospitalised_patients": 37434
#             }
#          },
#          "info": {
#             "date": "2021-01-01 00:00CET",
#             "date_generation": "2021-01-03 23:50",
#             "yesterday": "2020-12-31 00:00CET"
#          }
#       }
#    },
#    "metadata": {
#       "by": "Narrativa & AppliedXL",
#       "url": [
#          "wwww.narrativa.com",
#          "www.appliedxl.com"
#       ]
#    },
#    "total": {
#       "date": "2021-01-01",
#       "name": "Total",
#       "name_es": "Total",
#       "name_it": "Total",
#       "rid": "#total",
#       "source": "Narrativa",
#       "today_confirmed": 83899932,
#       "today_deaths": 1826966,
#       "today_new_confirmed": 540079,
#       "today_new_deaths": 9420,
#       "today_new_open_cases": -174859,
#       "today_new_recovered": 705518,
#       "today_open_cases": 26560773,
#       "today_recovered": 55512193,
#       "today_vs_yesterday_confirmed": 0.006478886185175892,
#       "today_vs_yesterday_deaths": 0.005182812429506578,
#       "today_vs_yesterday_open_cases": -0.006540297981360577,
#       "today_vs_yesterday_recovered": 0.012872848060934139,
#       "yesterday_confirmed": 83359853,
#       "yesterday_deaths": 1817546,
#       "yesterday_open_cases": 26735632,
#       "yesterday_recovered": 54806675
#    },
#    "updated_at": "2021-01-03 22:50UTC"
# }

# %% [markdown]
# La entrada que nos interesa es "total". Lo convertiremos cada petición a un dataframe con solo las columnas que nos interesan para después unir los dataframe en uno solo.

# %%
df_days = []
for data in data_days:
    df = pd.DataFrame.from_dict([data["total"]])
    df = df.set_index("date", drop = True)
    df_days.append(df[["today_new_confirmed", "today_new_deaths", "today_new_recovered"]])

# %% [markdown]
# Ahora combinaremos cada una de las series para formar el dataframe.

# %%
df_january = pd.concat(df_days)

# %% [markdown]
# Listo, ya tenemos nuestro datafram completo

# %%
df_january
# Out:
#             today_new_confirmed  today_new_deaths  today_new_recovered
# date
# 2021-01-01               540079              9420               705518
# 2021-01-02               622932              8277               126395
# 2021-01-03               531731              7361               302323
# 2021-01-04               550125             10125               456465
# 2021-01-05               678774             15452               389865
# 2021-01-06               770446             13767               410779
# 2021-01-07               923869             16098               431324
# 2021-01-08               813495             14799               379130
# 2021-01-09               764121             12734               438897
# 2021-01-10               562026              7712               310822
# 2021-01-11               644933             10640               400001
# 2021-01-12               705500             17342               431219
# 2021-01-13               748117             16357               455552
# 2021-01-14               755567             15320               487615
# 2021-01-15               766009             15055               371276
# 2021-01-16               619339             12981               416926
# 2021-01-17               549974              8743               351640
# 2021-01-18               489438              8829               386863
# 2021-01-18               236699              5408               208102
# 2021-01-20               693080             17542               500638
# 2021-01-21               679534             16745               403113
# 2021-01-22               660268             15887               475909
# 2021-01-23               569800             13277               414509
# 2021-01-24               445317              8814               346059
# 2021-01-25               506398             10590               396716
# 2021-01-26               552204             17378               441706
# 2021-01-27               525286             15379               604394
# 2021-01-28               654327             17843               278128
# 2021-01-29               611165             15771               424284
# 2021-01-30               515469             13556               412675
# 2021-01-31               381915              7934               358436
